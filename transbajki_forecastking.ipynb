# %% [markdown]
# <a href="https://colab.research.google.com/github/Karolina-Bogacka/transbajki/blob/master/transbajki_forecastking.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from functools import partial
import numpy as np
import requests
import glob
import datetime
from meteostat import Point, Daily, Stations, Hourly
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-6f2d11d15790> in <module>()
#       5 import glob
#       6 import datetime
# ----> 7 from meteostat import Point, Daily, Stations, Hourly
#
# ModuleNotFoundError: No module named 'meteostat'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !ls drive/MyDrive
# Out:
# 'Advanced ML (For the Non-Advanced) .gdoc'
#  Barrows.zip
#  CCPresentationNotes.gdoc
# 'CNN letter Dataset'
# 'Colab Notebooks'
#  content
#  data-local.zip
#  data.zip
#  Data.zip
# 'Deprecated: LineOfLeastResistance_Tests.gdoc'
# 'dlt :T:T:T:T:T:T:T.gdoc'
# 'Dokument bez tytułu (1).gdoc'
# 'Dokument bez tytułu.gdoc'
# 'fl experiments.gdoc'
#  frozen_east_text_detection.pb
#  git.gdoc
#  Github
# 'grouped-weather-rowerki(2).csv'
# 'IMG_4438[1705].gdoc'
# 'IMG_4438[1705].jpg'
#  IMG.gdoc
#  IMG.jpg
# 'Inni ludzie.gdoc'
# 'Jury Mail.gdoc'
#  masters.gdoc
#  master-thesis-results
# 'medytujący google docs.gdoc'
#  methodology.gdoc
# 'poetry generation.gdoc'
#  rowerki.zip
#  ssh.gdoc
#  Teams.gsheet
#  token.gdoc
#  trolls

# %%
# !pip install meteostat
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting meteostat
#   Downloading meteostat-1.6.2-py3-none-any.whl (31 kB)
# Requirement already satisfied: pandas>=1.1 in /usr/local/lib/python3.7/dist-packages (from meteostat) (1.3.5)
# Requirement already satisfied: pytz in /usr/local/lib/python3.7/dist-packages (from meteostat) (2022.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from meteostat) (1.21.6)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=1.1->meteostat) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas>=1.1->meteostat) (1.15.0)
# Installing collected packages: meteostat
# Successfully installed meteostat-1.6.2

# %%
! unzip drive/MyDrive/rowerki.zip
# Out:
# Archive:  drive/MyDrive/rowerki.zip
#    creating: rowerki/
#   inflating: rowerki/1651933303.csv
#   inflating: rowerki/1651389703.csv
#   inflating: rowerki/1650820903.csv
#   inflating: rowerki/1651130504.csv
#   inflating: rowerki/1651179104.csv
#   inflating: rowerki/1650925304.csv
#   inflating: rowerki/1651261903.csv
#   inflating: rowerki/1651645303.csv
#   inflating: rowerki/1651114303.csv
#   inflating: rowerki/1651936904.csv
#   inflating: rowerki/1650891104.csv
#   inflating: rowerki/1651593104.csv
#   inflating: rowerki/1651441903.csv
#   inflating: rowerki/1651690304.csv
#   inflating: rowerki/1651276304.csv
#   inflating: rowerki/1651008104.csv
#   inflating: rowerki/1651022504.csv
#   inflating: rowerki/1651116104.csv
#   inflating: rowerki/1651942303.csv
#   inflating: rowerki/1650903704.csv
#   inflating: rowerki/1651143104.csv
#   inflating: rowerki/1651425704.csv
#   inflating: rowerki/1651135904.csv
#   inflating: rowerki/1651411304.csv
#   inflating: rowerki/1651209704.csv
#   inflating: rowerki/1651350103.csv
#   inflating: rowerki/1651319503.csv
#   inflating: rowerki/1651850504.csv
#   inflating: rowerki/1650948704.csv
#   inflating: rowerki/1651233103.csv
#   inflating: rowerki/1651985503.csv
#   inflating: rowerki/1651413103.csv
#   inflating: rowerki/1651634504.csv
#   inflating: rowerki/1650939704.csv
#   inflating: rowerki/1651978303.csv
# 17  2022-05-01 00:51     2585263        97168        174    ok
# 18  2022-05-01 00:51     2585263        97161        174    ok
# 19  2022-05-01 00:51     2585263        97967        174    ok

# %% [markdown]
# Read all the csv files from directory

# %%
to_read = glob.glob("rowerki/*.csv")
rowerki_df = pd.concat(map(pd.read_csv, to_read))

# %%
rowerki_df.head()
# Out:
#                date  station_id  bike_number  bike_type state
# 0  2022-04-27 23:51     2585259        24900        174    ok
# 1  2022-04-27 23:51     2585259        24774        174    ok
# 2  2022-04-27 23:51     2585259        24584        174    ok
# 3  2022-04-27 23:51     2585259        28546        174    ok
# 4  2022-04-27 23:51     2585259        28356        174    ok

# %%
len(rowerki_df)
# Out:
# 11410902

# %% [markdown]
# Add those latitude longitude with request to nextbike api

# %%
json = requests.get("https://nextbike.net/maps/nextbike-official.json?city=372,210,475").json()
data = []
for city in json["countries"][0]['cities']:
    for place in city['places']:
        data.append({col: place[col] for col in ['uid', 'lat', 'lng', 'name','bike_racks']})
stations = pd.DataFrame(data)
stations.sort_values("bike_racks")
# Out:
#           uid        lat        lng                          name  bike_racks
# 329   2681635  52.234390  20.999159                Spektrum Tower          11
# 342  18751910  52.183037  20.991542           Signum Work Station          12
# 348  55316960  52.196220  20.938810                        Bolero          15
# 76    2585400  52.231450  20.988690               Prosta - Wronia          15
# 267   2586001  52.247314  21.042731        Metro Stadion Narodowy          15
# ..        ...        ...        ...                           ...         ...
# 201   2585885  52.157289  21.044008  Rosoła - Ciszewskiego - SGGW          30
# 207   2585901  52.142720  21.038362      Pileckiego - Alternatywy          30
# 60    2585369  52.244947  21.001294               Andersa - Długa          30
# 311   4393742  52.239409  21.031010  Metro Centrum Nauki Kopernik          30
# 0     2585259  52.296298  20.958358               Dewajtis - UKSW          30
#
# [349 rows x 5 columns]

# %%
rowerki_df = pd.merge(rowerki_df, stations, left_on='station_id', right_on='uid')
rowerki_df.head()
# Out:
#                date  station_id  bike_number  bike_type state      uid  \
# 0  2022-05-19 20:34     2585259        24935        174    ok  2585259
# 1  2022-05-19 20:34     2585259        24801        174    ok  2585259
# 2  2022-05-19 20:34     2585259        28659        174    ok  2585259
# 3  2022-05-19 20:34     2585259        26454        174    ok  2585259
# 4  2022-05-19 20:34     2585259        26105        174    ok  2585259
#
#          lat        lng             name  bike_racks
# 0  52.296298  20.958358  Dewajtis - UKSW          30
# 1  52.296298  20.958358  Dewajtis - UKSW          30
# 2  52.296298  20.958358  Dewajtis - UKSW          30
# 3  52.296298  20.958358  Dewajtis - UKSW          30
# 4  52.296298  20.958358  Dewajtis - UKSW          30

# %%
rowerki_df['hour'] = pd.to_datetime(rowerki_df['date']).dt.floor('H')
rowerki_df.head()
# Out:
#                date  station_id  bike_number  bike_type state      uid  \
# 0  2022-05-19 20:34     2585259        24935        174    ok  2585259
# 1  2022-05-19 20:34     2585259        24801        174    ok  2585259
# 2  2022-05-19 20:34     2585259        28659        174    ok  2585259
# 3  2022-05-19 20:34     2585259        26454        174    ok  2585259
# 4  2022-05-19 20:34     2585259        26105        174    ok  2585259
#
#          lat        lng             name  bike_racks                hour
# 0  52.296298  20.958358  Dewajtis - UKSW          30 2022-05-19 20:00:00
# 1  52.296298  20.958358  Dewajtis - UKSW          30 2022-05-19 20:00:00
# 2  52.296298  20.958358  Dewajtis - UKSW          30 2022-05-19 20:00:00
# 3  52.296298  20.958358  Dewajtis - UKSW          30 2022-05-19 20:00:00
# 4  52.296298  20.958358  Dewajtis - UKSW          30 2022-05-19 20:00:00

# %%
rowerki_df['hour'] = pd.to_datetime(rowerki_df['date']).dt.floor('H')
rowerki_df.head()
# Out:
#                date  station_id  bike_number  bike_type state      uid  \
# 0  2022-04-27 23:51     2585259        24900        174    ok  2585259
# 1  2022-04-27 23:51     2585259        24774        174    ok  2585259
# 2  2022-04-27 23:51     2585259        24584        174    ok  2585259
# 3  2022-04-27 23:51     2585259        28546        174    ok  2585259
# 4  2022-04-27 23:51     2585259        28356        174    ok  2585259
#
#          lat        lng             name  bike_racks                hour
# 0  52.296298  20.958358  Dewajtis - UKSW          30 2022-04-27 23:00:00
# 1  52.296298  20.958358  Dewajtis - UKSW          30 2022-04-27 23:00:00
# 2  52.296298  20.958358  Dewajtis - UKSW          30 2022-04-27 23:00:00
# 3  52.296298  20.958358  Dewajtis - UKSW          30 2022-04-27 23:00:00
# 4  52.296298  20.958358  Dewajtis - UKSW          30 2022-04-27 23:00:00

# %%
# let's begin with predicting just normal bikes
rowerki_df = rowerki_df[rowerki_df['bike_type']==174]
rowerki_df.head()
# Out:
#                date  station_id  bike_number  bike_type state      uid  \
# 0  2022-05-19 20:34     2585259        24935        174    ok  2585259
# 1  2022-05-19 20:34     2585259        24801        174    ok  2585259
# 2  2022-05-19 20:34     2585259        28659        174    ok  2585259
# 3  2022-05-19 20:34     2585259        26454        174    ok  2585259
# 4  2022-05-19 20:34     2585259        26105        174    ok  2585259
#
#          lat        lng             name  bike_racks                hour
# 0  52.296298  20.958358  Dewajtis - UKSW          30 2022-05-19 20:00:00
# 1  52.296298  20.958358  Dewajtis - UKSW          30 2022-05-19 20:00:00
# 2  52.296298  20.958358  Dewajtis - UKSW          30 2022-05-19 20:00:00
# 3  52.296298  20.958358  Dewajtis - UKSW          30 2022-05-19 20:00:00
# 4  52.296298  20.958358  Dewajtis - UKSW          30 2022-05-19 20:00:00

# %%
grouped_df = rowerki_df.groupby(['hour', 'station_id'])['bike_number'].nunique().reset_index()
grouped_df.head()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-15-cac792b72884> in <module>()
# ----> 1 grouped_df = rowerki_df.groupby(['hour', 'station_id'])['bike_number'].nunique().reset_index()
#       2 grouped_df.head()
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/groupby/generic.py in nunique(self, dropna)
#     634
#     635         codes, _ = algorithms.factorize(val, sort=False)
# --> 636         sorter = np.lexsort((codes, ids))
#     637         codes = codes[sorter]
#     638         ids = ids[sorter]
#
# <__array_function__ internals> in lexsort(*args, **kwargs)
#
# KeyboardInterrupt:

# %%
counted_correctly = rowerki_df.groupby(['date', 'station_id'])['bike_number'].nunique().reset_index()
counted_correctly.head()
# Out:
#                date  station_id  bike_number
# 0  2022-04-24 15:44      448565            3
# 1  2022-04-24 15:44      448566            3
# 2  2022-04-24 15:44     1154451            6
# 3  2022-04-24 15:44     2585259           19
# 4  2022-04-24 15:44     2585263           12

# %%
counted_correctly['hour'] = pd.to_datetime(counted_correctly['date']).dt.floor('H')
counted_correctly.head()
# Out:
#                date  station_id  bike_number                hour
# 0  2022-04-24 15:44      448565            3 2022-04-24 15:00:00
# 1  2022-04-24 15:44      448566            3 2022-04-24 15:00:00
# 2  2022-04-24 15:44     1154451            6 2022-04-24 15:00:00
# 3  2022-04-24 15:44     2585259           19 2022-04-24 15:00:00
# 4  2022-04-24 15:44     2585263           12 2022-04-24 15:00:00

# %%
counted_correctly.head()
# Out:
#                date  station_id  bike_number                hour
# 0  2022-04-24 15:44      448565            3 2022-04-24 15:00:00
# 1  2022-04-24 15:44      448566            3 2022-04-24 15:00:00
# 2  2022-04-24 15:44     1154451            6 2022-04-24 15:00:00
# 3  2022-04-24 15:44     2585259           19 2022-04-24 15:00:00
# 4  2022-04-24 15:44     2585263           12 2022-04-24 15:00:00

# %%
grouped_df['hour'] = grouped_df.hour.astype('datetime64[ns]')
counted_correctly['hour'] = counted_correctly.hour.astype('datetime64[ns]')
counted_correctly = pd.merge(counted_correctly, grouped_df, how='left',left_on=['hour', 'station_id'], right_on=['hour','station_id'])
counted_correctly.head()
# Out:
#                date  station_id  bike_number_x                hour  \
# 0  2022-04-24 15:44      448565              3 2022-04-24 15:00:00
# 1  2022-04-24 15:44      448566              3 2022-04-24 15:00:00
# 2  2022-04-24 15:44     1154451              6 2022-04-24 15:00:00
# 3  2022-04-24 15:44     2585259             19 2022-04-24 15:00:00
# 4  2022-04-24 15:44     2585263             12 2022-04-24 15:00:00
#
#    bike_number_y      uid        lat        lng             name  bike_racks  \
# 0              4   448565  52.183992  21.009840     Nestle House          15
# 1              3   448566  52.177909  20.997491         New City          15
# 2              6  1154451  52.230327  20.982705          Proximo          20
# 3             19  2585259  52.296298  20.958358  Dewajtis - UKSW          30
# 4             12  2585263  52.290974  20.929556    Metro Młociny          30
#
#    temp  dwpt  rhum  wdir  wspd    pres
# 0  15.0   4.1  48.0  50.0  19.0  1005.0
# 1  15.0   4.1  48.0  50.0  19.0  1005.0
# 2  15.0   4.1  48.0  50.0  19.0  1005.0
# 3  15.0   4.1  48.0  50.0  19.0  1005.0
# 4  15.0   4.1  48.0  50.0  19.0  1005.0

# %% [markdown]
# Encode station id and clean data before feeding it to an LSTM. Drop unnecessary columns. Discard long/lat data

# %%
counted_correctly.drop(['uid', 'bike_number_y', 'lat', 'lng', 'hour', 'name', 'bike_racks'],inplace=True, axis=1)
counted_correctly.head()
# Out:
#                date  station_id  bike_number_x  temp  dwpt  rhum  wdir  wspd  \
# 0  2022-04-24 15:44      448565              3  15.0   4.1  48.0  50.0  19.0
# 1  2022-04-24 15:44      448566              3  15.0   4.1  48.0  50.0  19.0
# 2  2022-04-24 15:44     1154451              6  15.0   4.1  48.0  50.0  19.0
# 3  2022-04-24 15:44     2585259             19  15.0   4.1  48.0  50.0  19.0
# 4  2022-04-24 15:44     2585263             12  15.0   4.1  48.0  50.0  19.0
#
#      pres
# 0  1005.0
# 1  1005.0
# 2  1005.0
# 3  1005.0
# 4  1005.0

# %%
counted_correctly

# %%
counted_correctly.corr()
# Out:
#                station_id  bike_number_x      temp      dwpt      rhum  \
# station_id       1.000000      -0.075433  0.003207  0.000824 -0.001749
# bike_number_x   -0.075433       1.000000 -0.080622  0.010764  0.075910
# temp             0.003207      -0.080622  1.000000  0.263991 -0.643234
# dwpt             0.000824       0.010764  0.263991  1.000000  0.544923
# rhum            -0.001749       0.075910 -0.643234  0.544923  1.000000
# wdir            -0.000050      -0.037641  0.249517  0.342036  0.075817
# wspd             0.004476      -0.034707  0.355764  0.242822 -0.143156
# pres            -0.001824      -0.002424 -0.242129 -0.745856 -0.380416
#
#                    wdir      wspd      pres
# station_id    -0.000050  0.004476 -0.001824
# bike_number_x -0.037641 -0.034707 -0.002424
# temp           0.249517  0.355764 -0.242129
# dwpt           0.342036  0.242822 -0.745856
# rhum           0.075817 -0.143156 -0.380416
# wdir           1.000000  0.268171 -0.275165
# wspd           0.268171  1.000000 -0.360406
# pres          -0.275165 -0.360406  1.000000

# %%
counted_correctly.drop(['bike_number'],inplace=True, axis=1)

# %%
counted_correctly.isnull().sum()
# Out:
# date             0
# station_id       0
# bike_number_x    0
# temp             0
# dwpt             0
# rhum             0
# wdir             0
# wspd             0
# pres             0
# dtype: int64

# %%
from sklearn.preprocessing import OrdinalEncoder

ord_enc = OrdinalEncoder()
counted_correctly["station_id"] = ord_enc.fit_transform(counted_correctly[["station_id"]])
counted_correctly.head(11)
# Out:
#                 date  station_id  bike_number_x  temp  dwpt  rhum  wdir  wspd  \
# 0   2022-04-24 15:44         0.0              3  15.0   4.1  48.0  50.0  19.0
# 1   2022-04-24 15:44         1.0              3  15.0   4.1  48.0  50.0  19.0
# 2   2022-04-24 15:44         2.0              6  15.0   4.1  48.0  50.0  19.0
# 3   2022-04-24 15:44         3.0             19  15.0   4.1  48.0  50.0  19.0
# 4   2022-04-24 15:44         4.0             12  15.0   4.1  48.0  50.0  19.0
# 5   2022-04-24 15:44         5.0             16  15.0   4.1  48.0  50.0  19.0
# 6   2022-04-24 15:44         6.0              8  15.0   4.1  48.0  50.0  19.0
# 7   2022-04-24 15:44         7.0             12  15.0   4.1  48.0  50.0  19.0
# 8   2022-04-24 15:44         8.0              1  15.0   4.1  48.0  50.0  19.0
# 9   2022-04-24 15:44         9.0             13  15.0   4.1  48.0  50.0  19.0
# 10  2022-04-24 15:44        10.0              3  15.0   4.1  48.0  50.0  19.0
#
#       pres
# 0   1005.0
# 1   1005.0
# 2   1005.0
# 3   1005.0
# 4   1005.0
# 5   1005.0
# 6   1005.0
# 7   1005.0
# 8   1005.0
# 9   1005.0
# 10  1005.0

# %%
len(counted_correctly)
# Out:
# 851790

# %% [markdown]
# Scale weather values

# %%
counted_correctly['date'] = pd.to_numeric(pd.to_datetime(counted_correctly.date))
counted_correctly.head()
# Out:
#                   date  station_id  bike_number_x  temp  dwpt  rhum  wdir  \
# 0  1650815040000000000         0.0              3  15.0   4.1  48.0  50.0
# 1  1650815040000000000         1.0              3  15.0   4.1  48.0  50.0
# 2  1650815040000000000         2.0              6  15.0   4.1  48.0  50.0
# 3  1650815040000000000         3.0             19  15.0   4.1  48.0  50.0
# 4  1650815040000000000         4.0             12  15.0   4.1  48.0  50.0
#
#    wspd    pres
# 0  19.0  1005.0
# 1  19.0  1005.0
# 2  19.0  1005.0
# 3  19.0  1005.0
# 4  19.0  1005.0

# %%
counted_values = counted_correctly.values
counted_values = counted_values.astype('float32')

# %%
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler(feature_range=(0, 1))

counted_correctly[[ 'date','bike_number_x', 'station_id','temp', 'dwpt', 'rhum', 'wdir', 'wspd', 'pres']] = scaler.fit_transform(counted_correctly[[ 'date','bike_number_x', 'station_id','temp', 'dwpt', 'rhum', 'wdir', 'wspd', 'pres']])

# %%
counted_correctly.head()
# Out:
#    date  station_id  bike_number_x      temp      dwpt      rhum      wdir  \
# 0   0.0    0.000000       0.010256  0.509804  0.432292  0.358025  0.138889
# 1   0.0    0.002976       0.010256  0.509804  0.432292  0.358025  0.138889
# 2   0.0    0.005952       0.025641  0.509804  0.432292  0.358025  0.138889
# 3   0.0    0.008929       0.092308  0.509804  0.432292  0.358025  0.138889
# 4   0.0    0.011905       0.056410  0.509804  0.432292  0.358025  0.138889
#
#        wspd      pres
# 0  0.395833  0.074074
# 1  0.395833  0.074074
# 2  0.395833  0.074074
# 3  0.395833  0.074074
# 4  0.395833  0.074074

# %%
counted_correctly.date.value_counts()
# Out:
# 0.023355    333
# 0.064482    333
# 0.017373    333
# 0.018121    333
# 0.018868    333
#            ...
# 0.613410    288
# 0.247682    287
# 0.249925    284
# 0.612911    284
# 0.248430    280
# Name: date, Length: 2662, dtype: int64

# %%
counted_correctly.sort_values(by=['date', 'station_id'], inplace=True)

# %%
test_split=round(len(counted_correctly)*0.10)
df_for_training=counted_correctly[:-test_split]
df_for_testing=counted_correctly[-test_split:]
print(df_for_training.shape)
print(df_for_testing.shape)
# Out:
# (766611, 9)
# (85179, 9)

# %%
df_for_training.head()
# Out:
#    date  station_id  bike_number_x      temp      dwpt      rhum      wdir  \
# 0   0.0    0.000000       0.010256  0.509804  0.432292  0.358025  0.138889
# 1   0.0    0.002976       0.010256  0.509804  0.432292  0.358025  0.138889
# 2   0.0    0.005952       0.025641  0.509804  0.432292  0.358025  0.138889
# 3   0.0    0.008929       0.092308  0.509804  0.432292  0.358025  0.138889
# 4   0.0    0.011905       0.056410  0.509804  0.432292  0.358025  0.138889
#
#        wspd      pres
# 0  0.395833  0.074074
# 1  0.395833  0.074074
# 2  0.395833  0.074074
# 3  0.395833  0.074074
# 4  0.395833  0.074074

# %%
train_X=np.array(df_for_training)

# %%
def createXY(dataset,n_past):
    dataX = []
    dataY = []
    for i in range(n_past, len(dataset)):
            dataX.append(dataset[i - n_past:i, 0:dataset.shape[1]])
            dataY.append(dataset[i,0])
    return np.array(dataX),np.array(dataY)

trainX,trainY=np.array(df_for_training[['date','station_id', 'temp', 'dwpt', 'rhum', 'wdir', 'wspd', 'pres']]), np.array(df_for_training['bike_number_x'])
testX,testY=np.array(df_for_testing[['date','station_id', 'temp', 'dwpt', 'rhum', 'wdir', 'wspd', 'pres']]), np.array(df_for_testing['bike_number_x'])

# %%
trainX.shape, trainY.shape, testX.shape, testY.shape
# Out:
# ((766611, 8), (766611,), (85179, 8), (85179,))

# %%
trainX = trainX.reshape((trainX.shape[0], 1, trainX.shape[1]))
testX = testX.reshape((testX.shape[0], 1, testX.shape[1]))

# %%
from math import sqrt
from numpy import concatenate
from matplotlib import pyplot
from pandas import read_csv
from pandas import DataFrame
from pandas import concat
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import mean_squared_error
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM


model = Sequential()
model.add(LSTM(50, input_shape=(trainX.shape[1], trainX.shape[2])))
model.add(Dense(1))
model.compile(loss='mae', optimizer='adam')
# fit network
history = model.fit(trainX, trainY, epochs=50, batch_size=72, validation_data=(testX, testY), verbose=2, shuffle=False)
# plot history
pyplot.plot(history.history['loss'], label='train')
pyplot.plot(history.history['val_loss'], label='test')
pyplot.legend()
pyplot.show()
# Out:
# Epoch 1/50
# 10648/10648 - 30s - loss: 0.0309 - val_loss: 0.0323 - 30s/epoch - 3ms/step
# Epoch 2/50
# 10648/10648 - 27s - loss: 0.0309 - val_loss: 0.0325 - 27s/epoch - 3ms/step
# Epoch 3/50
# 10648/10648 - 27s - loss: 0.0307 - val_loss: 0.0325 - 27s/epoch - 2ms/step
# Epoch 4/50
# 10648/10648 - 27s - loss: 0.0298 - val_loss: 0.0362 - 27s/epoch - 2ms/step
# Epoch 5/50
# 10648/10648 - 27s - loss: 0.0297 - val_loss: 0.0365 - 27s/epoch - 3ms/step
# Epoch 6/50
# 10648/10648 - 27s - loss: 0.0297 - val_loss: 0.0353 - 27s/epoch - 3ms/step
# Epoch 7/50
# 10648/10648 - 30s - loss: 0.0296 - val_loss: 0.0341 - 30s/epoch - 3ms/step
# Epoch 8/50
# 10648/10648 - 27s - loss: 0.0296 - val_loss: 0.0332 - 27s/epoch - 3ms/step
# Epoch 9/50
# 10648/10648 - 26s - loss: 0.0296 - val_loss: 0.0327 - 26s/epoch - 2ms/step
# Epoch 10/50
# 10648/10648 - 29s - loss: 0.0296 - val_loss: 0.0322 - 29s/epoch - 3ms/step
# Epoch 11/50
# 10648/10648 - 27s - loss: 0.0295 - val_loss: 0.0321 - 27s/epoch - 3ms/step
# Epoch 12/50
# 10648/10648 - 27s - loss: 0.0295 - val_loss: 0.0319 - 27s/epoch - 2ms/step
# Epoch 13/50
# 10648/10648 - 27s - loss: 0.0295 - val_loss: 0.0318 - 27s/epoch - 3ms/step
# Epoch 14/50
# 10648/10648 - 29s - loss: 0.0294 - val_loss: 0.0317 - 29s/epoch - 3ms/step
# Epoch 15/50
# 10648/10648 - 28s - loss: 0.0294 - val_loss: 0.0316 - 28s/epoch - 3ms/step
# Epoch 16/50
# 10648/10648 - 27s - loss: 0.0294 - val_loss: 0.0315 - 27s/epoch - 3ms/step
# Epoch 17/50
# 10648/10648 - 28s - loss: 0.0293 - val_loss: 0.0315 - 28s/epoch - 3ms/step
# Epoch 18/50
# 10648/10648 - 30s - loss: 0.0293 - val_loss: 0.0314 - 30s/epoch - 3ms/step
# Epoch 19/50
# 10648/10648 - 28s - loss: 0.0293 - val_loss: 0.0314 - 28s/epoch - 3ms/step
# Epoch 20/50
# 10648/10648 - 29s - loss: 0.0293 - val_loss: 0.0313 - 29s/epoch - 3ms/step
# Epoch 21/50
# 10648/10648 - 28s - loss: 0.0293 - val_loss: 0.0313 - 28s/epoch - 3ms/step
# Epoch 22/50
# 10648/10648 - 28s - loss: 0.0293 - val_loss: 0.0312 - 28s/epoch - 3ms/step
# Epoch 23/50
# 10648/10648 - 29s - loss: 0.0293 - val_loss: 0.0312 - 29s/epoch - 3ms/step
# Epoch 24/50
# 10648/10648 - 29s - loss: 0.0293 - val_loss: 0.0313 - 29s/epoch - 3ms/step
# Epoch 25/50
# 10648/10648 - 29s - loss: 0.0293 - val_loss: 0.0313 - 29s/epoch - 3ms/step
# Epoch 26/50
# 10648/10648 - 28s - loss: 0.0292 - val_loss: 0.0313 - 28s/epoch - 3ms/step
# Epoch 27/50
# 10648/10648 - 28s - loss: 0.0292 - val_loss: 0.0314 - 28s/epoch - 3ms/step
# Epoch 28/50
# 10648/10648 - 30s - loss: 0.0292 - val_loss: 0.0313 - 30s/epoch - 3ms/step
# Epoch 29/50
# 10648/10648 - 28s - loss: 0.0292 - val_loss: 0.0314 - 28s/epoch - 3ms/step
# Epoch 30/50
# 10648/10648 - 28s - loss: 0.0292 - val_loss: 0.0314 - 28s/epoch - 3ms/step
# Epoch 31/50
# 10648/10648 - 29s - loss: 0.0292 - val_loss: 0.0313 - 29s/epoch - 3ms/step
# Epoch 32/50
# 10648/10648 - 28s - loss: 0.0292 - val_loss: 0.0314 - 28s/epoch - 3ms/step
# Epoch 33/50
# 10648/10648 - 28s - loss: 0.0292 - val_loss: 0.0313 - 28s/epoch - 3ms/step
# Epoch 34/50
# 10648/10648 - 29s - loss: 0.0292 - val_loss: 0.0314 - 29s/epoch - 3ms/step
# Epoch 35/50
# 10648/10648 - 28s - loss: 0.0292 - val_loss: 0.0314 - 28s/epoch - 3ms/step
# Epoch 36/50
# 10648/10648 - 26s - loss: 0.0292 - val_loss: 0.0314 - 26s/epoch - 2ms/step
# Epoch 37/50
# 10648/10648 - 26s - loss: 0.0292 - val_loss: 0.0315 - 26s/epoch - 2ms/step
# Epoch 38/50
# 10648/10648 - 27s - loss: 0.0292 - val_loss: 0.0315 - 27s/epoch - 3ms/step
# Epoch 39/50
# 10648/10648 - 26s - loss: 0.0292 - val_loss: 0.0316 - 26s/epoch - 2ms/step
# Epoch 40/50
# 10648/10648 - 27s - loss: 0.0292 - val_loss: 0.0316 - 27s/epoch - 3ms/step
# Epoch 41/50
# 10648/10648 - 27s - loss: 0.0292 - val_loss: 0.0316 - 27s/epoch - 3ms/step
# Epoch 42/50
# 10648/10648 - 25s - loss: 0.0292 - val_loss: 0.0316 - 25s/epoch - 2ms/step
# Epoch 43/50
# 10648/10648 - 26s - loss: 0.0292 - val_loss: 0.0316 - 26s/epoch - 2ms/step
# Epoch 44/50
# 10648/10648 - 28s - loss: 0.0292 - val_loss: 0.0316 - 28s/epoch - 3ms/step
# Epoch 45/50
# 10648/10648 - 27s - loss: 0.0292 - val_loss: 0.0315 - 27s/epoch - 3ms/step
# Epoch 46/50
# 10648/10648 - 28s - loss: 0.0292 - val_loss: 0.0315 - 28s/epoch - 3ms/step
# Epoch 47/50
# 10648/10648 - 28s - loss: 0.0292 - val_loss: 0.0315 - 28s/epoch - 3ms/step
# Epoch 48/50
# 10648/10648 - 30s - loss: 0.0292 - val_loss: 0.0315 - 30s/epoch - 3ms/step
# Epoch 49/50
# 10648/10648 - 28s - loss: 0.0292 - val_loss: 0.0314 - 28s/epoch - 3ms/step
# Epoch 50/50
# 10648/10648 - 28s - loss: 0.0292 - val_loss: 0.0314 - 28s/epoch - 3ms/step

# %%
pred = model.predict(testX)

# %%
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure

figure(figsize=(12, 10), dpi=80)
epochs = [i for i in range(len(testY))]
plt.plot(epochs, pred-testY, 'm', label="Differences")
plt.xlabel('Epoch of training') 
plt.ylabel('Predictions of bike number') 
plt.legend()

# %%
 import tensorflow as tf
 
 lstm_model = tf.keras.models.Sequential([
   tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(200, return_sequences=True), 
                                input_shape=trainX.shape[-2:]),
     tf.keras.layers.Dense(20, activation='tanh'),
     tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(150)),
     tf.keras.layers.Dense(20, activation='tanh'),
     tf.keras.layers.Dense(20, activation='tanh'),
     tf.keras.layers.Dropout(0.25),
     tf.keras.layers.Dense(1),
 ])
 lstm_model.compile(optimizer='adam', loss='mse')
 lstm_model.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional_6 (Bidirectio  (None, 1, 400)           334400
#  nal)
#
#  dense_12 (Dense)            (None, 1, 20)             8020
#
#  bidirectional_7 (Bidirectio  (None, 300)              205200
#  nal)
#
#  dense_13 (Dense)            (None, 20)                6020
#
#  dense_14 (Dense)            (None, 20)                420
#
#  dropout_3 (Dropout)         (None, 20)                0
#
#  dense_15 (Dense)            (None, 1)                 21
#
# =================================================================
# Total params: 554,081
# Trainable params: 554,081
# Non-trainable params: 0
# _________________________________________________________________

# %%
tf.config.run_functions_eagerly(True)

# %%
history = lstm_model.fit(trainX,trainY, batch_size=72, epochs=2,validation_data=(testX, testY),verbose=1)
# Out:
# Epoch 1/2
# UserWarning: Even though the `tf.config.experimental_run_functions_eagerly` option is set, this option does not apply to tf.data functions. To force eager execution of tf.data functions, please use `tf.data.experimental.enable_debug_mode()`.
# 10648/10648 [==============================] - 815s 77ms/step - loss: 0.0017 - val_loss: 0.0018
# Epoch 2/2
# 10648/10648 [==============================] - 813s 76ms/step - loss: 0.0016 - val_loss: 0.0018

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(16,9))
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train loss', 'validation loss'])
plt.show()

# %%
grouped_df.station_id.value_counts()
# Out:
# 2585464    670
# 2585963    670
# 2585992    670
# 2585982    670
# 2585972    670
#           ...
# 8746360    404
# 3318614     61
# 2676298     46
# 3318697     26
# 3318744      1
# Name: station_id, Length: 337, dtype: int64

# %%
grouped_df['encoded_id'] = ord_enc.fit_transform(grouped_df[["station_id"]])
grouped_df.encoded_id.value_counts()
# Out:
# 112.0    670
# 248.0    670
# 264.0    670
# 258.0    670
# 253.0    670
#         ...
# 323.0    404
# 310.0     61
# 294.0     46
# 311.0     26
# 312.0      1
# Name: encoded_id, Length: 337, dtype: int64

# %%
counted_correctly.station_id.value_counts()
# Out:
# 126.0    2662
# 95.0     2662
# 25.0     2662
# 290.0    2662
# 296.0    2662
#          ...
# 323.0    1430
# 310.0     359
# 294.0      91
# 311.0      51
# 312.0       1
# Name: station_id, Length: 337, dtype: int64

# %%
counted_correctly.drop_duplicates(subset ='hour', keep = False, inplace = True)
grouped_df.drop_duplicates(subset ='hour', keep = False, inplace = True)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-36-428d592e4b5d> in <module>()
#       1 counted_correctly.drop_duplicates(subset ='hour', keep = False, inplace = True)
# ----> 2 grouped_df.drop_duplicates(subset ='hour', keep = False, inplace = True)
#
# /usr/local/lib/python3.7/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# TypeError: drop_duplicates() got an unexpected keyword argument 'subset'

# %%
grouped_df = pd.merge(grouped_df, stations, left_on='station_id', right_on='uid')
grouped_df.head()
# Out:
#                  hour  station_id  bike_number   uid_x      lat_x     lng_x  \
# 0 2022-04-24 15:00:00      448565            4  448565  52.183992  21.00984
# 1 2022-04-24 16:00:00      448565            5  448565  52.183992  21.00984
# 2 2022-04-24 17:00:00      448565           10  448565  52.183992  21.00984
# 3 2022-04-24 18:00:00      448565            7  448565  52.183992  21.00984
# 4 2022-04-24 19:00:00      448565            7  448565  52.183992  21.00984
#
#          name_x  bike_racks_x  temp  dwpt  rhum  wdir  wspd    pres   uid_y  \
# 0  Nestle House            15  15.0   4.1  48.0  50.0  19.0  1005.0  448565
# 1  Nestle House            15  14.0   4.0  51.0  50.0  15.0  1004.0  448565
# 2  Nestle House            15  14.0   4.0  51.0  50.0  20.0  1003.0  448565
# 3  Nestle House            15  12.4   4.4  58.0  60.0  18.0  1004.3  448565
# 4  Nestle House            15  13.0   3.9  54.0  70.0  19.0  1004.0  448565
#
#        lat_y     lng_y        name_y  bike_racks_y
# 0  52.183992  21.00984  Nestle House            15
# 1  52.183992  21.00984  Nestle House            15
# 2  52.183992  21.00984  Nestle House            15
# 3  52.183992  21.00984  Nestle House            15
# 4  52.183992  21.00984  Nestle House            15

# %%
def get_weather(row):
  # weather for the hour (more or less) of the measurement
  start = row['hour'].to_pydatetime()
  end = row['hour'].to_pydatetime()
  location = Point(float(row.lat), float(row.lng), 100)
  data = Hourly(location, start, end)
  data = data.fetch()
  row['temp'] = data['temp']
  row['dwpt'] = data['dwpt']
  row['rhum'] = data['rhum']
  row['wdir'] = data['wdir']
  row['wspd'] = data['wspd']
  row['pres'] = data['pres']

grouped_df = grouped_df.apply(get_weather, axis=1)
grouped_df.head()

# %%
from google.colab import files

grouped_df.to_csv('grouped-weather-rowerki.csv', encoding = 'utf-8-sig') 
files.download('grouped-weather-rowerki.csv')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-f36472f4af58> in <module>()
#       1 from google.colab import files
#       2
# ----> 3 grouped_df.to_csv('grouped-weather-rowerki.csv', encoding = 'utf-8-sig')
#       4 files.download('grouped-weather-rowerki.csv')
#
# NameError: name 'grouped_df' is not defined

# %%
grouped_df = pd.read_csv('drive/MyDrive/grouped-weather-rowerki(2).csv', index_col='Unnamed: 0')
grouped_df.head()
# Out:
#                   hour  station_id  bike_number     uid        lat       lng  \
# 0  2022-04-24 15:00:00      448565            4  448565  52.183992  21.00984
# 1  2022-04-24 16:00:00      448565            5  448565  52.183992  21.00984
# 2  2022-04-24 17:00:00      448565           10  448565  52.183992  21.00984
# 3  2022-04-24 18:00:00      448565            7  448565  52.183992  21.00984
# 4  2022-04-24 19:00:00      448565            7  448565  52.183992  21.00984
#
#            name  bike_racks  temp  dwpt  rhum  wdir  wspd    pres
# 0  Nestle House          15  15.0   4.1  48.0  50.0  19.0  1005.0
# 1  Nestle House          15  14.0   4.0  51.0  50.0  15.0  1004.0
# 2  Nestle House          15  14.0   4.0  51.0  50.0  20.0  1003.0
# 3  Nestle House          15  12.4   4.4  58.0  60.0  18.0  1004.3
# 4  Nestle House          15  13.0   3.9  54.0  70.0  19.0  1004.0

# %%
len(grouped_df)
# Out:
# 218729

# %%
grouped_df.drop_duplicates(inplace=True)
grouped_df.head()
# Out:
#                   hour  station_id  bike_number     uid        lat       lng  \
# 0  2022-04-24 15:00:00      448565            4  448565  52.183992  21.00984
# 1  2022-04-24 16:00:00      448565            5  448565  52.183992  21.00984
# 2  2022-04-24 17:00:00      448565           10  448565  52.183992  21.00984
# 3  2022-04-24 18:00:00      448565            7  448565  52.183992  21.00984
# 4  2022-04-24 19:00:00      448565            7  448565  52.183992  21.00984
#
#            name  bike_racks  temp  dwpt  rhum  wdir  wspd    pres
# 0  Nestle House          15  15.0   4.1  48.0  50.0  19.0  1005.0
# 1  Nestle House          15  14.0   4.0  51.0  50.0  15.0  1004.0
# 2  Nestle House          15  14.0   4.0  51.0  50.0  20.0  1003.0
# 3  Nestle House          15  12.4   4.4  58.0  60.0  18.0  1004.3
# 4  Nestle House          15  13.0   3.9  54.0  70.0  19.0  1004.0

# %%
len(grouped_df)
# Out:
# 218729

# %%
grouped_df.head()
# Out:
#                  hour  station_id  bike_number     uid        lat       lng  \
# 0 2022-04-24 15:00:00      448565            4  448565  52.183992  21.00984
# 1 2022-04-24 16:00:00      448565            5  448565  52.183992  21.00984
# 2 2022-04-24 17:00:00      448565           10  448565  52.183992  21.00984
# 3 2022-04-24 18:00:00      448565            7  448565  52.183992  21.00984
# 4 2022-04-24 19:00:00      448565            7  448565  52.183992  21.00984
#
#            name  bike_racks  temp  dwpt  rhum  wdir  wspd    pres
# 0  Nestle House          15  15.0   4.1  48.0  50.0  19.0  1005.0
# 1  Nestle House          15  14.0   4.0  51.0  50.0  15.0  1004.0
# 2  Nestle House          15  14.0   4.0  51.0  50.0  20.0  1003.0
# 3  Nestle House          15  12.4   4.4  58.0  60.0  18.0  1004.3
# 4  Nestle House          15  13.0   3.9  54.0  70.0  19.0  1004.0

# %%
sample = rowerki_df.iloc[0]

# %%
# Set time period
start = sample['hour'].to_pydatetime()
end = sample['hour'].to_pydatetime()

# Create Point for Vancouver, BC
location = Point(float(sample.lat), float(sample.lng), 100)

# Get daily data for 2018
data = Hourly(location, start, end)
data = data.fetch()
data
# Out:
#                      temp  dwpt  rhum  prcp  snow  wdir  wspd  wpgt    pres  \
# time
# 2022-04-27 23:00:00   9.0   0.9  57.0   0.0   NaN  60.0   7.0  16.7  1024.0
#
#                      tsun  coco
# time
# 2022-04-27 23:00:00   NaN   2.0

# %%
rowerki_df['hour'] = pd.to_datetime(rowerki_df['date']).dt.floor('H')
rowerki_df.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-215c1460c32b> in <module>()
# ----> 1 rowerki_df['hour'] = pd.to_datetime(rowerki_df['date']).dt.floor('H')
#       2 rowerki_df.head()
#
# NameError: name 'pd' is not defined

# %%
rowerki_df['bike_number'].unique()
# Out:
# array([24900, 24774, 24584, ..., 24862, 91715, 26489])

# %%
rowerki_df.bike_type.value_counts()
# will have to encode later and probably do separate predictions for each maybe
# Out:
# 174    10159021
# 4        834343
# 37       252643
# 35        82808
# 34        80909
# 14          744
# 0           270
# 84          159
# 114           5
# Name: bike_type, dtype: int64

# %%
grouped_df = rowerki_df.groupby(['hour', 'station_id', 'bike_type'])['bike_number'].nunique().reset_index()
grouped_df.head()
# Out:
#                  hour  station_id  bike_type  bike_number
# 0 2022-04-24 15:00:00      448565        174            4
# 1 2022-04-24 15:00:00      448566        174            3
# 2 2022-04-24 15:00:00     1154451        174            6
# 3 2022-04-24 15:00:00     2585259        174           19
# 4 2022-04-24 15:00:00     2585263        174           12

# %%
rowerki_df[rowerki_df.state != "ok"]
# Out:
# Empty DataFrame
# Columns: [date, station_id, bike_number, bike_type, state, hour]
# Index: []

# %% [markdown]
# XD all the gathered bikes are ok, so nothing interesting there
#
# Let's just lose the state then, since it won't be of any use anyway

# %%
rowerki_df.drop('state', inplace=True, axis=1)

# %%
rowerki_df.head()
# Out:
#                date  station_id  bike_number  bike_type                hour
# 0  2022-04-27 23:51     2585259        24900        174 2022-04-27 23:00:00
# 1  2022-04-27 23:51     2585259        24774        174 2022-04-27 23:00:00
# 2  2022-04-27 23:51     2585259        24584        174 2022-04-27 23:00:00
# 3  2022-04-27 23:51     2585259        28546        174 2022-04-27 23:00:00
# 4  2022-04-27 23:51     2585259        28356        174 2022-04-27 23:00:00

# %%
rowerki_df["date"] = pd.to_datetime(rowerki_df["date"])

# %%
rowerki_df.bike_type.value_counts()
# Out:
# 174    10159021
# 4        834343
# 37       252643
# 35        82808
# 34        80909
# 14          744
# 0           270
# 84          159
# 114           5
# Name: bike_type, dtype: int64

# %% [markdown]
# try with that weather fetching

# %%
sample_stat = stations[stations.name=="Spektrum Tower"]
int(sample_stat['uid'])
# Out:
# 2681635

# %%
sample_rowerki_date = rowerki_df[rowerki_df.station_id == int(sample_stat['uid'])]['date']
sample_rowerki_date
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-17-9cff08d0d894> in <module>()
# ----> 1 sample_rowerki_date = rowerki_df[rowerki_df.station_id == int(sample_stat['uid'])]['date']
#       2 sample_rowerki_date
#
# NameError: name 'sample_stat' is not defined

# %%
sample_stat.lat
# Out:
# 329    52.23439
# Name: lat, dtype: float64

# %% [markdown]
# Znaczenie tych całych kodów typów
#
# var AVAILABLE_BIKES = 'Dostępne rowery: ';
# var SPOTS = 'Wolne stojaki: ';
# var TANDEMS = 'Tandemy: ';
# var KID_BIKES = 'Dziecięce: ';
# var NORMAL_BIKES = 'Zwykłe rowery: ';
# var ELECTRIC_BIKES = 'Elektryczne: ';
#
# var TANDEM_ID = 26;
#
# var KID_ID_4 = 34;
# var KID_ID_6 = 35;
#
# var ELECTRIC_ID = 37;
#
# var STANDARD_ID = 174;
#
# var MISSED_BIKES_PLACE_TYPE_ID = 1;

# %%
# Set time period
start = datetime.datetime(2018, 1, 1, 21, 0)
end = datetime.datetime(2018, 1, 1, 23, 0)

# Create Point for Vancouver, BC
location = Point(float(sample_stat.lat), float(sample_stat.lng), 100)

# Get daily data for 2018
data = Hourly(location, start, end)
data = data.fetch()
data
# Out:
#                      temp  dwpt  rhum  prcp  snow   wdir  wspd  wpgt    pres  \
# time
# 2018-01-01 21:00:00   4.9   2.9  87.0   NaN   NaN  210.0   3.6   NaN  1005.9
# 2018-01-01 22:00:00   2.8   1.6  92.0   NaN   NaN  190.0   3.6   NaN  1006.3
# 2018-01-01 23:00:00   2.3   1.7  96.0   NaN   NaN  160.0   3.6   NaN  1006.6
#
#                      tsun  coco
# time
# 2018-01-01 21:00:00   NaN   NaN
# 2018-01-01 22:00:00   NaN   NaN
# 2018-01-01 23:00:00   NaN   NaN

# %% [markdown]
# Looks successful, might be worth it to try and add weather in some form

# %%
rowerki_df.head()
# Out:
#                  date  station_id  bike_number  bike_type                hour
# 0 2022-04-27 23:51:00     2585259        24900        174 2022-04-27 23:00:00
# 1 2022-04-27 23:51:00     2585259        24774        174 2022-04-27 23:00:00
# 2 2022-04-27 23:51:00     2585259        24584        174 2022-04-27 23:00:00
# 3 2022-04-27 23:51:00     2585259        28546        174 2022-04-27 23:00:00
# 4 2022-04-27 23:51:00     2585259        28356        174 2022-04-27 23:00:00

# %% [markdown]
# Add also bike number and number of racks, to see which stations get swamped and how often, and maybe build prediction system based on that.

# %%
bikes = rowerki_df
bikes['prev_station'] = bikes\
.sort_values(by=['date'], kind='stable')\
.groupby(['bike_number'])\
.shift(1)['station_id'].astype('Int64')
bikes['next_station'] = bikes\
.sort_values(by=['date'], kind='stable')\
.groupby(['bike_number'])\
.shift(-1)['station_id'].astype('Int64')
# You can't do next != current because it does not detect loops
bikes['just_returned'] = bikes\
.sort_values(by=['date'], kind='stable')\
.groupby(['bike_number', 'station_id'])\
.shift(1)['date'].isna() | (bikes['prev_station'] != bikes['station_id'])
bikes['just_rented'] = bikes\
.sort_values(by=['date'], kind='stable')\
.groupby(['bike_number', 'station_id'])\
.shift(-1)['date'].isna() | (bikes['next_station'] != bikes['station_id'])
bikes[bikes['bike_number'] == 96033].sort_values(by=['date'], kind='stable')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-102-71d4b6d9a91e> in <module>()
#       1 bikes = rowerki_df
# ----> 2 bikes['prev_station'] = bikes.sort_values(by=['date'], kind='stable').groupby(['bike_number']).shift(1)['station_id'].astype('Int64')
#       3 bikes['next_station'] = bikes.sort_values(by=['date'], kind='stable').groupby(['bike_number']).shift(-1)['station_id'].astype('Int64')
#       4 # You can't do next != current because it does not detect loops
#       5 bikes['just_returned'] = bikes.sort_values(by=['date'], kind='stable').groupby(['bike_number', 'station_id']).shift(1)['date'].isna() | (bikes['prev_station'] != bikes['station_id'])
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py in __setitem__(self, key, value)
#    3610         else:
#    3611             # set column
# -> 3612             self._set_item(key, value)
#    3613
#    3614     def _setitem_slice(self, key: slice, value):
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py in _set_item(self, key, value)
#    3782         ensure homogeneity.
#    3783         """
# -> 3784         value = self._sanitize_column(value)
#    3785
#    3786         if (
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py in _sanitize_column(self, value)
#    4504         # We should never get here with DataFrame value
#    4505         if isinstance(value, Series):
# -> 4506             return _reindex_for_setitem(value, self.index)
#    4507
#    4508         if is_list_like(value):
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py in _reindex_for_setitem(value, index)
#   10773     # GH#4107
#   10774     try:
# > 10775         reindexed_value = value.reindex(index)._values
#   10776     except ValueError as err:
#   10777         # raised in MultiIndex.from_tuples, see test_insert_error_msmgs
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/series.py in reindex(self, index, **kwargs)
#    4578     )
#    4579     def reindex(self, index=None, **kwargs):
# -> 4580         return super().reindex(index=index, **kwargs)
#    4581
#    4582     @deprecate_nonkeyword_arguments(version=None, allowed_args=["self", "labels"])
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/generic.py in reindex(self, *args, **kwargs)
#    4817         # perform the reindex on the axes
#    4818         return self._reindex_axes(
# -> 4819             axes, level, limit, tolerance, method, fill_value, copy
#    4820         ).__finalize__(self, method="reindex")
#    4821
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/generic.py in _reindex_axes(self, axes, level, limit, tolerance, method, fill_value, copy)
#    4833             ax = self._get_axis(a)
#    4834             new_index, indexer = ax.reindex(
# -> 4835                 labels, level=level, limit=limit, tolerance=tolerance, method=method
#    4836             )
#    4837
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexes/base.py in reindex(self, target, method, level, limit, tolerance)
#    3832                             "with a method or limit"
#    3833                         )
# -> 3834                     indexer, _ = self.get_indexer_non_unique(target)
#    3835
#    3836         if preserve_names and target.nlevels == 1 and target.name != self.name:
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexes/base.py in get_indexer_non_unique(self, target)
#    5256         tgt_values = target._get_engine_target()
#    5257
# -> 5258         indexer, missing = self._engine.get_indexer_non_unique(tgt_values)
#    5259         return ensure_platform_int(indexer), ensure_platform_int(missing)
#    5260
#
# /usr/local/lib/python3.7/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_indexer_non_unique()
#
# <__array_function__ internals> in resize(*args, **kwargs)
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py in resize(a, new_shape)
#    1430
#    1431     repeats = -(-new_size // a.size)  # ceil division
# -> 1432     a = concatenate((a,) * repeats)[:new_size]
#    1433
#    1434     return reshape(a, new_shape)
#
# <__array_function__ internals> in concatenate(*args, **kwargs)
#
# KeyboardInterrupt:

# %%
grouped = bikes\
.groupby(['date', 'station_id'])\
.aggregate({'bike_number' : len, 'just_returned' : sum,'just_rented' : sum})\
.reset_index()\
.rename(columns={'bike_number': 'bike_count'})\
.merge(stations,left_on = 'station_id', right_on = 'uid')
grouped['just_rented'] = grouped.sort_values(['date']).groupby('station_id').shift(1)['just_rented']
grouped

# %% [markdown]
# 1. Get weather from the historical api (maybe preprocess it somehow or add feature engineering)
# 2. Add traffic as returned/taken maybe
# 3. Prediction with Lstm maybe for both depending on the station too (don't think latitude/longitude will help, but index of station id probably yes, but

# %% [markdown]
# https://www.kaggle.com/code/elmahy/a3t-gcn-for-traffic-forecasting/notebook
# https://towardsdatascience.com/predicting-no-of-bike-share-users-machine-learning-data-visualization-project-using-r-71bc1b9a7495
# (- here the number of bikes driving around on a given day in total, but may still be useful)
# https://medium.com/towards-data-science/cityclass-project-eng-15bc5fcd8e1
# (- interesting for the way it recognizes types of buildings nearby and can therefore explain a lot of predictions)
